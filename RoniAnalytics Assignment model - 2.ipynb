# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\muralidharan.m\Downloads\binance-futures_derivative_ticker_2020-02-01_BTCUSDT.csv.gz")

# %%
print(data)
# Out:
#               exchange   symbol         timestamp   local_timestamp  \
# 0      binance-futures  BTCUSDT  1580515202348000  1580515202497335
# 1      binance-futures  BTCUSDT  1580515203000000  1580515206719191
# 2      binance-futures  BTCUSDT  1580515205360000  1580515207578119
# 3      binance-futures  BTCUSDT  1580515209000000  1580515209511558
# 4      binance-futures  BTCUSDT  1580515212000000  1580515212268289
# ...                ...      ...               ...               ...
# 34116  binance-futures  BTCUSDT  1580601585001000  1580601585185946
# 34117  binance-futures  BTCUSDT  1580601588000000  1580601588183011
# 34118  binance-futures  BTCUSDT  1580601591000000  1580601591262901
# 34119  binance-futures  BTCUSDT  1580601594000000  1580601594185022
# 34120  binance-futures  BTCUSDT  1580601597000000  1580601597258099
#
#        funding_timestamp  funding_rate  predicted_funding_rate  open_interest  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34121 entries, 0 to 34120
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   exchange                34121 non-null  object
#  1   symbol                  34121 non-null  object
#  2   timestamp               34121 non-null  int64
#  3   local_timestamp         34121 non-null  int64
#  4   funding_timestamp       34120 non-null  float64
#  5   funding_rate            34120 non-null  float64
#  6   predicted_funding_rate  0 non-null      float64
#  7   open_interest           0 non-null      float64
#  8   last_price              34121 non-null  float64
#  9   index_price             0 non-null      float64
#  10  mark_price              34120 non-null  float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 2.6+ MB

# %%
data.columns
# Out:
# Index(['exchange', 'symbol', 'timestamp', 'local_timestamp',
#        'funding_timestamp', 'funding_rate', 'predicted_funding_rate',
#        'open_interest', 'last_price', 'index_price', 'mark_price'],
#       dtype='object')

# %%
data.head(10)
# Out:
#           exchange   symbol         timestamp   local_timestamp  \
# 0  binance-futures  BTCUSDT  1580515202348000  1580515202497335
# 1  binance-futures  BTCUSDT  1580515203000000  1580515206719191
# 2  binance-futures  BTCUSDT  1580515205360000  1580515207578119
# 3  binance-futures  BTCUSDT  1580515209000000  1580515209511558
# 4  binance-futures  BTCUSDT  1580515212000000  1580515212268289
# 5  binance-futures  BTCUSDT  1580515215000000  1580515215232238
# 6  binance-futures  BTCUSDT  1580515217681000  1580515217824346
# 7  binance-futures  BTCUSDT  1580515218000000  1580515218264271
# 8  binance-futures  BTCUSDT  1580515221000000  1580515221269123
# 9  binance-futures  BTCUSDT  1580515224000000  1580515224203603
#
#    funding_timestamp  funding_rate  predicted_funding_rate  open_interest  \
# 0                NaN           NaN                     NaN            NaN
# 1       1.580544e+15       0.00075                     NaN            NaN
# ...

# %%
data.tail(15)
# Out:
#               exchange   symbol         timestamp   local_timestamp  \
# 34106  binance-futures  BTCUSDT  1580601556095000  1580601556227651
# 34107  binance-futures  BTCUSDT  1580601558000000  1580601558244721
# 34108  binance-futures  BTCUSDT  1580601561000000  1580601561180454
# 34109  binance-futures  BTCUSDT  1580601564000000  1580601564254806
# 34110  binance-futures  BTCUSDT  1580601567000000  1580601567185907
# 34111  binance-futures  BTCUSDT  1580601570001000  1580601570250004
# 34112  binance-futures  BTCUSDT  1580601573000000  1580601573194020
# 34113  binance-futures  BTCUSDT  1580601576000000  1580601576180060
# 34114  binance-futures  BTCUSDT  1580601579000000  1580601579181502
# 34115  binance-futures  BTCUSDT  1580601582000000  1580601582206529
# 34116  binance-futures  BTCUSDT  1580601585001000  1580601585185946
# 34117  binance-futures  BTCUSDT  1580601588000000  1580601588183011
# 34118  binance-futures  BTCUSDT  1580601591000000  1580601591262901
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=34121, step=1)

# %%
len(data)
# Out:
# 34121

# %%
data.describe()
# Out:
#           timestamp  local_timestamp  funding_timestamp  funding_rate  \
# count  3.412100e+04     3.412100e+04       3.412000e+04  34120.000000
# mean   1.580558e+15     1.580558e+15       1.580573e+15      0.000560
# std    2.472782e+10     2.472782e+10       2.334199e+10      0.000194
# min    1.580515e+15     1.580515e+15       1.580544e+15      0.000241
# 25%    1.580537e+15     1.580537e+15       1.580544e+15      0.000357
# 50%    1.580558e+15     1.580558e+15       1.580573e+15      0.000612
# 75%    1.580579e+15     1.580579e+15       1.580602e+15      0.000700
# max    1.580602e+15     1.580602e+15       1.580602e+15      0.000835
#
#        predicted_funding_rate  open_interest    last_price  index_price  \
# count                     0.0            0.0  34121.000000          0.0
# mean                      NaN            NaN   9393.193080          NaN
# std                       NaN            NaN     32.080269          NaN
# ...

# %%
data['last_price'].unique()
# Out:
# array([9364.51, 9366.63, 9376.71, ..., 9392.81, 9392.82, 9394.07])

# %%
len(data['last_price'].unique())
# Out:
# 4069

# %%
data['mark_price'].unique()
# Out:
# array([          nan, 9358.64672637, 9361.2619624 , ..., 9386.45117041,
#        9386.34542763, 9386.01757959])

# %%
len(data['mark_price'].unique())
# Out:
# 28772

# %%
data['funding_timestamp'].unique()
# Out:
# array([          nan, 1.5805440e+15, 1.5805728e+15, 1.5806016e+15])

# %%
len(data['funding_timestamp'].unique())
# Out:
# 4

# %%
data['local_timestamp'].unique()
# Out:
# array([1580515202497335, 1580515206719191, 1580515207578119, ...,
#        1580601591262901, 1580601594185022, 1580601597258099], dtype=int64)

# %%
len(data['local_timestamp'].unique())
# Out:
# 34121

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [exchange, symbol, timestamp, local_timestamp, funding_timestamp, funding_rate, predicted_funding_rate, open_interest, last_price, index_price, mark_price]
# Index: []

# %%
data.drop('index_price', axis=1)
# Out:
#               exchange   symbol         timestamp   local_timestamp  \
# 0      binance-futures  BTCUSDT  1580515202348000  1580515202497335
# 1      binance-futures  BTCUSDT  1580515203000000  1580515206719191
# 2      binance-futures  BTCUSDT  1580515205360000  1580515207578119
# 3      binance-futures  BTCUSDT  1580515209000000  1580515209511558
# 4      binance-futures  BTCUSDT  1580515212000000  1580515212268289
# ...                ...      ...               ...               ...
# 34116  binance-futures  BTCUSDT  1580601585001000  1580601585185946
# 34117  binance-futures  BTCUSDT  1580601588000000  1580601588183011
# 34118  binance-futures  BTCUSDT  1580601591000000  1580601591262901
# 34119  binance-futures  BTCUSDT  1580601594000000  1580601594185022
# 34120  binance-futures  BTCUSDT  1580601597000000  1580601597258099
#
#        funding_timestamp  funding_rate  predicted_funding_rate  open_interest  \
# ...

# %%
data.loc[1137]
# Out:
# exchange                     binance-futures
# symbol                               BTCUSDT
# timestamp                   1580518089000000
# local_timestamp             1580518089188123
# funding_timestamp         1580544000000000.0
# funding_rate                        0.000811
# predicted_funding_rate                   NaN
# open_interest                            NaN
# last_price                           9380.37
# index_price                              NaN
# mark_price                          9381.435
# Name: 1137, dtype: object

# %%
data.isna().sum()
# Out:
# exchange                      0
# symbol                        0
# timestamp                     0
# local_timestamp               0
# funding_timestamp             1
# funding_rate                  1
# predicted_funding_rate    34121
# open_interest             34121
# last_price                    0
# index_price               34121
# mark_price                    1
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data['index_price'],data['timestamp'].plot(kind = 'box')
# Out:
# (0       NaN
#  1       NaN
#  2       NaN
#  3       NaN
#  4       NaN
#           ..
#  34116   NaN
#  34117   NaN
#  34118   NaN
#  34119   NaN
#  34120   NaN
#  Name: index_price, Length: 34121, dtype: float64,
#  <AxesSubplot:>)

# %%
data['last_price'],data['mark_price'].plot(kind = 'line')
# Out:
# (0        9364.51
#  1        9364.51
#  2        9366.63
#  3        9366.63
#  4        9366.63
#            ...
#  34116    9394.07
#  34117    9394.07
#  34118    9394.07
#  34119    9394.07
#  34120    9394.07
#  Name: last_price, Length: 34121, dtype: float64,
#  <AxesSubplot:>)

# %%
data['funding_timestamp'],data['last_price'].plot(kind = 'hist')
# Out:
# (0                 NaN
#  1        1.580544e+15
#  2        1.580544e+15
#  3        1.580544e+15
#  4        1.580544e+15
#               ...
#  34116    1.580602e+15
#  34117    1.580602e+15
#  34118    1.580602e+15
#  34119    1.580602e+15
#  34120    1.580602e+15
#  Name: funding_timestamp, Length: 34121, dtype: float64,
#  <AxesSubplot:ylabel='Frequency'>)

# %%
data.corr()
# Out:
#                         timestamp  local_timestamp  funding_timestamp  \
# timestamp                1.000000         1.000000           0.941807
# local_timestamp          1.000000         1.000000           0.941807
# funding_timestamp        0.941807         0.941807           1.000000
# funding_rate            -0.973437        -0.973437          -0.940801
# predicted_funding_rate        NaN              NaN                NaN
# open_interest                 NaN              NaN                NaN
# last_price              -0.437356        -0.437356          -0.426044
# index_price                   NaN              NaN                NaN
# mark_price              -0.425350        -0.425350          -0.403514
#
#                         funding_rate  predicted_funding_rate  open_interest  \
# timestamp                  -0.973437                     NaN            NaN
# local_timestamp            -0.973437                     NaN            NaN
# ...

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)
